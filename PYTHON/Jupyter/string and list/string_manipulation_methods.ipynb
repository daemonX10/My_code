# %% [markdown]
# #### string manipulation
# string are used to record text information such as name. in python, strings act as "sequence" which means pythons tracks every element in the strings as sa sequence. This one of the important features of python language.
# for example, python understand the string"hello" to be a sequence of letters in a specific order which means the indexing technique to grab particular letters (like first letter or the last letter).
# as we now know string conains set of characters ,let's check how can we manipulate and take subset of string, how can we access character out string and do some manipulation on strings .
# subset of string can be access by using slice operator[] or [:] (string index starts with 0 and -1 at the end ). Lets look at the example.

# %%
# single word 
'hello'
# Out:
# 'hello'

# %%
# entering the phase 
'This is also a string'
# Out:
# 'This is also a string'

# %%
# we can use double quote 
"string built with double quotes"
# Out:
# 'string built with double quotes'

# %%
#be careful with quotes! 
'i'm using single quotes , but will create an error'
# Out:
#   Cell In[5], line 2
#     'i'm using single quotes , but will create an error'
#                                                        ^
# SyntaxError: unterminated string literal (detected at line 2)

# %% [markdown]
# The above code results in an error as the text "i'm" stops the string. Here , a combination of single quotes and double quotes can be used to get the complete statement

# %%
"Now I'm ready to use the single quotes inside a string!"
# Out:
# "Now I'm ready to use the single quotes inside a string!"

# %% [markdown]
# #### <font color='red' > Python 3 Alert </font>

# %% [markdown]
# Note that , in python 3 , print is a function and not a statement . so you would print statements like this:
# print('Hello world')
# if you want to use this functionality in python2 ,you can import form the __future__ module.
# **caution: After importing this; you won't be able to choose the print statement method anymore . So pick the right one whichever you prefer depending on your python installation and continue on wiht it. **

# %%
# to use print function form pyton 3 in python 2 
from __future__ import print_function
print('hello world')
# Out:
# hello world

# %%
string="eren yeager"
print(string)
# Out:
# eren yeager

# %% [markdown]
# ### string operation

# %% [markdown]
# ### accessing element form string
# we know string are a sequence , which means python can use indexes to call all the sequence parts. Let's learn how string indexing works .
# 1. we use brackets [] after an object to call its index.
# 2. we should also note that indexing starts at 0 for python .
# Now , let's create a new object called and the walk thorugh a few examples of indexing .

# %%
# fetch first character of string 
print(string[0])
# Out:
# e

# %%
# fetch last element of a string 
print(string[-1])
# Out:
# r

# %%
# fetch nth element of a string 
print(string [5])
# Out:
# y

# %% [markdown]
# ##### if length exceeds, then it will give index out of range as we are finding index

# %%
print(string[14])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 print(string[14])
#
# IndexError: string index out of range

# %% [markdown]
# ##### We can use a : to perform *slicing* which grabs everything up to a designated point. For example:
#
# 1. This slice operation will help us to fetch substring from a string.
# 2. [Index given before colon will be starting index and index given after colon will be ending index and
# it is not considered to print]
# 3. And if no index is given it will consider till end of string index

# %%
print(string[1:])
# Out:
# ren yeager

# %%
# this will give character staring form index 1 and ending index 2 (last will not consider for slice operation)
print(string[1:3])
# Out:
# re

# %% [markdown]
# ##### Note the above slicing. Here we're telling Python to grab everything from 1 up to 3. It doesn't include the 3rd index. You'll notice this a lot in Python, where statements and are usually in the context of "up to, but not including".

# %%
# It will give all characters but not the last three characeters 
print(string[:-3])
# Out:
# eren yea

# %%
# It will give all the characters but not he first two characeters 
print(string[2:])
# Out:
# en yeager

# %% [markdown]
# Index and slice notation is used to grab elements of a sequenec by a specified step size (where in 1 is the default size). For instance we can use two colons in a row and then a number specifying the frequency to grab elements. For example:

# %%
#Grab everything, but go in steps size of 1
s="Hey , you know one thing , we both are same"
s[::1]
# Out:
# 'Hey , you know one thing , we both are same'

# %%
# Grab everything, but go in step sizes of 2
s[::2]
# Out:
# 'Hy,yuko n hn  ebt r ae'

# %%
# we can use this to print a string backwords
s[::-1]
# Out:
# 'emas era htob ew , gniht eno wonk uoy , yeH'

# %% [markdown]
# Immutability is one the finest string property whichh is created once and the elements within it cannot be changed or replaced. For example:

# %%
# Let's try to change the first letter to "x"
s[0]='x'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 2
#       1 # Let's try to change the first letter to "x"
# ----> 2 s[0]='x'
#
# TypeError: 'str' object does not support item assignment

# %%
# We can reassing s completely though!
s=s+" concatenate me!" 
s
# Out:
# 'Hey , you know one thing , we both are sameconcatenate me! concatenate me! concatenate me!'

# %%
# string can be concatenate using + sign operator 
print(string + " company")
# Out:
# eren yeager company

# %%
print("hello" + "world")
# Out:
# helloworld

# %%
#print string two times using * operator 
#WE can use the multiplication symbol to create repetition 
print(string*2)
# Out:
# eren yeagereren yeager

# %% [markdown]
# ### string length

# %%
# to find length of string 
# we can use len
len(string)
# Out:
# 11

# %% [markdown]
# #### find character/word in a string

# %%
# to find a character in a string , use find and it will give index of that character
#if not able to find it will give -1
string.find("o") 
string.find("n")
# Out:
# 3

# %% [markdown]
# ### cound character in a string

# %%
# To count no.of characters in a string, can use count method
print(string.count(''))
# Out:
# 12

# %% [markdown]
# ### string split operation

# %%
# To split string at ceratin space/character ,will return list of strings after splitting

# %%
string.split('n')
# Out:
# ['ere', ' yeager']

# %% [markdown]
# ### Change string to upper & Lower case

# %%
# changes to upper case
string="eren yeager"
print(string.upper())
# Out:
# EREN YEAGER

# %%
#change ot lower case 
print(string.lower())
# Out:
# eren yeager

# %%
#swop case from lower to upper & upper to lower
print(string.swapcase())
# Out:
# EREN YEAGER

# %%
# FOR FIRST LETTER CAPTILE OF EACH WORD 
print(string.title())
# Out:
# Eren Yeager

# %%
# FOR capital letter of a word
print(string.capitalize())
# Out:
# Eren yeager

# %% [markdown]
# #### Reverse String

# %%
# can use reversed for reversing string . basically for reversing each sentence in sting 
print(' '.join(reversed(string)))
print(string[::-1])
# Out:
# r e g a e y   n e r e
# regaey nere

# %%
# we can do reverse of string by extended slice functionlity [::-1] , so here the third one id the optional step size
# through which we are reversing by using step size as -1
print(string[::-2])
# Out:
# rge ee

# %% [markdown]
# Removing characters From the end of the string

# %%
string_a=" never give up "

# %%
string_a
# Out:
# ' never give up '

# %%
# strip will remove white space from both end of the strings 
string_a.strip(" ")
# Out:
# ' never give up '

# %%
# removes leading character from a string
string_a.lstrip(" ")
# Out:
# 'never give up '

# %%
# remove trailing character from a string
string_a.rstrip(" pu evig")
# Out:
# ' never'

# %% [markdown]
# #### Join operation in string

# %%
# to add space in between each characters
" ".join("welcome to attack on titan")
# Out:
# 'w e l c o m e   t o   a t t a c k   o n   t i t a n'

# %% [markdown]
# #### replacing String

# %%
string_n="greetings to my girl"
string_n.replace("to","from")
# Out:
# 'greetings from my girl'

# %% [markdown]
# ### Formatting
# The <font color="yellow"> center()</font> method allow youto place your string 'centered' between a provided string with a certain length.

# %%
string="eren yeager"
string.center(20,' ')
# Out:
# '    eren yeager     '

# %% [markdown]
# <font color='yellow'>Expandtabs()</font> will expand tab notation \t into spaces . Let's ssee an example to understand the concept.

# %%
'hello\thi'.expandtabs()
# Out:
# 'hello   hi'

# %% [markdown]
# ### Checking string case

# %%
# check if string are in upper case 
string.isupper()
# Out:
# False

# %%
# check if string are in lower case
string.islower()
# Out:
# True

# %%
# check if string contains space 
string.isspace()
# Out:
# False

# %%
# Check if string contains digit
string.isdigit()
# Out:
# False

# %%
#check if string endswith character n
string.endswith('r')
# Out:
# True

# %%
# check if all char in string are alphanumeric 
a="abcd1234"
a.isalnum()
# Out:
# True

# %% [markdown]
# iterate through a string

# %%
# iterating through a string and count letters in a string 
count=0
for ch in 'Greetings from celestia':
    count+=1
    print(count,'letters found')
# Out:
# 1 letters found
# 2 letters found
# 3 letters found
# 4 letters found
# 5 letters found
# 6 letters found
# 7 letters found
# 8 letters found
# 9 letters found
# 10 letters found
# 11 letters found
# 12 letters found
# 13 letters found
# 14 letters found
# 15 letters found
# 16 letters found
# 17 letters found
# 18 letters found
# 19 letters found
# 20 letters found
# 21 letters found
# 22 letters found
# 23 letters found

# %%
string="my celestia"
print(id(string))
string.replace("my" , "cute")
print(id(string))
# Out:
# 1956521179952
# 1956521179952

# %%
name="soul celestia"
vowels ="AaEeIiOoUu"
for ch in name:
    if ch in vowels:
        print("{} is a vowel".format(ch))
    else:
        print("{} is not a vowel".format(ch))
# Out:
# s is not a vowel
# o is a vowel
# u is a vowel
# l is not a vowel
#   is not a vowel
# c is not a vowel
# e is a vowel
# l is not a vowel
# e is a vowel
# s is not a vowel
# t is not a vowel
# i is a vowel
# a is a vowel

# %%
# Defining a function called `palindrome_check` that takes a single parameter `str`.
def palindrome_check(str):
    # looping form 0 to len(str)/2
    for i in range(0,int(len(str)/2)):
        if str[i] !=str[len(str)-i-1]:
            return False
    return True
s="malayalam"
res=palindrome_check(s)

if(res):
    print("yes string is palindrome")
else:
    print("no string is not palindrome")
# Out:
# yes string is palindrome

# %%
str="malyalam"
int(len(str)/2)
# Out:
# 4
